# %%
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature = 0.1,
    tiktoken_model_name="gpt-3.5-turbo",
    verbose=True
)

memory= ConversationSummaryBufferMemory(
    llm = llm,
    max_token_limit=120,
    memory_key="chat_history" #메모리키에 것을 다른 곳에서 이용하기 위해서
)

template = """
    You are a helpful AI talking to a human
    
    {chat_history} #template에 chat_history를 가지고 와서 넣어주기 위해서
    Human:{question}
    You:
"""

chain = LLMChain(
    llm=llm,
    memory = memory,
    prompt = PromptTemplate.from_template(template)
)

chain.predict(question="My name is Nico")
# Out:
# "Hello, Nico! It's nice to meet you. How can I assist you today?"

# %%
chain.predict(question="I live in Seoul")
# Out:
# "That's great, Nico! Seoul is a vibrant city with a rich culture and history. What do you enjoy most about living there?"

# %%
chain.predict(question="What is my name")
# Out:
# 'Your name is Nico! How can I help you today, Nico?'

# %%
memory.load_memory_variables({})
# Out:
# {'history': "System: The human introduces himself as Nico and mentions that he lives in Seoul. The AI expresses pleasure in meeting Nico and asks how it can assist him today, highlighting Seoul's vibrant culture, rich history, modern architecture, and various activities, while inviting Nico to share any specific questions or topics about the city.\nHuman: What is my name\nAI: I'm sorry, but I don't have access to personal information about you unless you've shared it in this conversation. How can I assist you today?"}
