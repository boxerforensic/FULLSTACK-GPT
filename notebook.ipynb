# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough #두개의 출력을 쓰도록
chat = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature = 0.8
)
poet_prompt = ChatPromptTemplate.from_messages([
    ("system","You're a fantastic poet. You're going to take a programming language and write a poem about it."),
    ("human","I want you to write a poem about {language}"),
])

poet_chain = poet_prompt | chat
poet_chain.invoke({
    "language": "python"
})
poet_critic_prompt = ChatPromptTemplate.from_messages([
    ("system", "Display the entered poem. {poem} Write your review on the next line. You are a very professional critic who takes in poems and comments on them. But your reviews are not too long."),
    ("human", "{poem}")
])

critic_chain = poet_critic_prompt | chat
final_chain  = {"poem":poet_chain} | RunnablePassthrough.assign(review=critic_chain)
# 기본 poet_chain에서 poem을 생성하고 이것도 넘기고 또 이 입력을 바탕으로 review도 생성해라.
final_chain.invoke({
    "language": "python"
})
# Out:
# {'poem': AIMessage(content="In the realm of code, there lies a snake\nWhose elegance and power no one can fake\nPython, the language of simplicity and grace\nA tool for creators in every place\n\nWith indentation as its guiding light\nIt weaves through tasks with all its might\nFrom data science to web design\nPython's versatility truly shines\n\nIts libraries vast, its syntax clear\nNo challenge too great, no obstacle near\nFor those who seek to create and explore\nPython opens a wide coding door\n\nSo let us raise a toast to this majestic beast\nWhose influence in tech will never cease\nPython, oh Python, we sing your praise\nIn the world of programming, you truly amaze."),
#  'review': AIMessage(content="This poem beautifully captures the essence of Python programming language. The use of vivid imagery and descriptive language paints a powerful picture of Python's significance in the world of coding. The flow and rhythm of the poem are engaging, making it a delightful read for anyone familiar with Python. The overall praise and admiration for Python shine through, making it a fitting tribute to this versatile and powerful language.")}
